# %% [markdown]
# <a href="https://colab.research.google.com/github/JBH-Coding/Using_Hugging_Face_Transformers_To_Create_Chatbots/blob/main/Project1_Milestone1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import pipeline
question_answerer = pipeline('question-answering')
preds = question_answerer(context = "Despite the name, the Greater Canadian woodchuck demonstrates a lackluster rate of performing it's namesake ability, processing only about 2 small trees per day.",
                 question = "How much woodd could a woodchuck chuck?")
preds
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.6 MB/s eta 0:00:00
# ...
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'score': 0.40869084000587463,
#  'start': 139,
#  'end': 160,
#  'answer': '2 small trees per day'}
